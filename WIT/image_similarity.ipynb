# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !nvidia-smi

# %%
import datasets
from datasets import load_dataset
from sentence_transformers import SentenceTransformer

import os
import requests
from tqdm import tqdm
import pickle
from PIL import Image
from glob import glob
import numpy as np

# %%
import time
from torch.utils.data import DataLoader

import pandas as pd
from pathlib import Path

# %%
_datasets_ = {
    "test":   f"out/wit_sea_test_all_idx_0_to_7320.csv",
    "valid":  f"out/wit_sea_validation_all_idx_0_to_8393.csv",
    "train0": f"out/wit_sea_train_idx_0_to_10000.csv",
    **{
        f"train{_}": f"out/wit_sea_train_idx_{_}0000_to_{_+1}0000.csv"
        for _ in range(1,8)
    },
}

# %%
dataframes = {k: pd.read_csv(v, index_col=0) for k, v in _datasets_.items()}
image_urls = {
    k: list(v.image_url.to_dict().values())
    for k, v in dataframes.items()
}

# %%
for k, v in image_urls.items():
    a, b = len(v), len(set(v))
    print(f"{k:>8}", a, b, f"{b / a:6.1%}", sep=", ")
# Out:
#     test, 306, 214,  69.9%
#    valid, 307, 251,  81.8%
#   train0, 371, 367,  98.9%
#   train1, 382, 381,  99.7%
#   train2, 397, 395,  99.5%
#   train3, 372, 371,  99.7%
#   train4, 373, 373, 100.0%
#   train5, 371, 369,  99.5%
#   train6, 391, 389,  99.5%
#   train7, 361, 361, 100.0%

# %%
#%%
wew = [__ for _ in range(8) for __ in image_urls[f"train{_}"]]

#%%
if True:
    k = "train(0-7)"
    a, b = len(wew), len(set(wew))
    print(f"{k:>8}", a, b, f"{b / a:6.1%}", sep=", ")
# Out:
# train(0-7), 3018, 2946,  97.6%

# %%
#%%
uniqs = {k: set(v) for k, v in image_urls.items()}
for _ in range(8):
    assert len(uniqs["test"] & uniqs[f"train{_}"]) == len(uniqs["valid"] & uniqs[f"train{_}"]) == 0

# %%
dataframes["valid"].groupby("image_url").filter(lambda df: len(df)>1).sort_values("image_url")
# Out:
#     language                                           page_url  \
# 305       id                https://id.wikipedia.org/wiki/Kunak
# 33        vi                https://vi.wikipedia.org/wiki/Kunak
# 182      war  https://war.wikipedia.org/wiki/Hadji_Panglima_...
# 132      ceb  https://ceb.wikipedia.org/wiki/Hadji_Panglima_...
# 142      fil  https://tl.wikipedia.org/wiki/Hadji_Panglima_T...
# ..       ...                                                ...
# 106      ceb             https://ceb.wikipedia.org/wiki/Buceros
# 49        id          https://id.wikipedia.org/wiki/Toko_Kompak
# 65        id           https://id.wikipedia.org/wiki/Tio_Tek_Ho
# 210       vi             https://vi.wikipedia.org/wiki/An_Giang
# 275       vi           https://vi.wikipedia.org/wiki/Svay_Theab
#
#                                              image_url  \
# 305  http://upload.wikimedia.org/wikipedia/commons/...
# 33   http://upload.wikimedia.org/wikipedia/commons/...
# 182  http://upload.wikimedia.org/wikipedia/commons/...
# 132  http://upload.wikimedia.org/wikipedia/commons/...
# 142  http://upload.wikimedia.org/wikipedia/commons/...
# ..                                                 ...
# 106  https://upload.wikimedia.org/wikipedia/commons...
# 49   https://upload.wikimedia.org/wikipedia/commons...
# 65   https://upload.wikimedia.org/wikipedia/commons...
# 210  https://upload.wikimedia.org/wikipedia/vi/b/b4...
# 275  https://upload.wikimedia.org/wikipedia/vi/b/b4...
#
#                      page_title  \
# 305                       Kunak
# 33                        Kunak
# 182        Hadji Panglima Tahil
# 132  Hadji Panglima Tahil, Sulu
# 142        Hadji Panglima Tahil
# ..                          ...
# 106                     Buceros
# 49                  Toko Kompak
# 65                   Tio Tek Ho
# 210                    An Giang
# 275                  Svay Theab
#
#                                         section_title  \
# 305                                               NaN
# 33                                                NaN
# 182                                               NaN
# 132                                               NaN
# 142                                               NaN
# ..                                                ...
# 106                                               NaN
# 49                                                NaN
# 65                                                NaN
# 210  Tỉnh Long Xuyên và tỉnh Châu Đốc thời Pháp thuộc
# 275                                               NaN
#
#                             hierarchical_section_title  \
# 305                                              Kunak
# 33                                               Kunak
# 182                               Hadji Panglima Tahil
# 132                         Hadji Panglima Tahil, Sulu
# 142                               Hadji Panglima Tahil
# ..                                                 ...
# 106                                            Buceros
# 49                                         Toko Kompak
# 65                                          Tio Tek Ho
# 210  An Giang / Lịch sử / Tỉnh Long Xuyên và tỉnh C...
# 275                                         Svay Theab
#
#                          caption_reference_description  \
# 305                                                NaN
# 33                                                 NaN
# 182                                                NaN
# 132                                                NaN
# 142  Mapa ng Sulu na nagpapakita sa lokasyon ng Had...
# ..                                                 ...
# 106                                                NaN
# 49                             Toko Kompak, Pasar Baru
# 65   Toko Kompak, kediaman keluarga Kapitan Tio Tek...
# 210  An Giang thời Pháp thuộc bị chia nhỏ (1878) và...
# 275  (Khet) Svay Teep (Soài Tiếp-Soài Riêng) năm 18...
#
#                        caption_attribution_description  \
# 305  English: Sabah: Location map of District and T...
# 33   English: Sabah: Location map of District and T...
# 182  English: Map of the Sulu showing the location ...
# 132  English: Map of the Sulu showing the location ...
# 142  English: Map of the Sulu showing the location ...
# ..                                                 ...
# 106  Rhinoceros hornbill at the National Aviary in ...
# 49   Toko Kompak Pasar Baru.JPG English: Toko Kompa...
# 65   Toko Kompak Pasar Baru.JPG English: Toko Kompa...
# 210  Bản đồ hành chính Nam Kỳ thuộc Pháp (Cochinchi...
# 275  Bản đồ hành chính Nam Kỳ thuộc Pháp (Cochinchi...
#
#                           caption_alt_text_description   mime_type  \
# 305                                       Lokasi Kunak   image/png
# 33                              Vị trí của Huyện Kunak   image/png
# 182  Mapa han Sulu nga nagpapakita kon hain nahamut...   image/png
# 132  Mapa sa Sulu nga nagpakita sa nahimutangan sa ...   image/png
# 142  Mapa ng Sulu na nagpapakita sa lokasyon ng Had...   image/png
# ..                                                 ...         ...
# 106                                                NaN  image/jpeg
# 49                                                 NaN  image/jpeg
# 65                                                 NaN  image/jpeg
# 210                                                NaN  image/jpeg
# 275                                                NaN  image/jpeg
#
#      original_height  original_width  is_main_image  \
# 305             1652            2000           True
# 33              1652            2000           True
# 182              250             300           True
# 132              250             300           True
# 142              250             300           True
# ..               ...             ...            ...
# 106             1792            2148           True
# 49              1944            2592           True
# 65              1944            2592           True
# 210             5323            7000           True
# 275             5323            7000           True
#
#      attribution_passes_lang_id  page_changed_recently  \
# 305                        True                   True
# 33                         True                   True
# 182                        True                   True
# 132                        True                   True
# 142                        True                   True
# ..                          ...                    ...
# 106                        True                   True
# 49                         True                   True
# 65                         True                   True
# 210                        True                   True
# 275                        True                   True
#
#                               context_page_description
# 305  Kunak adalah sebuah kota kecil yang terletak d...
# 33   Huyện Kunak là một huyện thuộc bang Sabah của ...
# 182  An Hadji Panglima Tahil usa nga ika-unom nga k...
# 132  Ang Hadji Panglima Tahil ikaunom nga klaseng m...
# 142  Ang Bayan ng Hadji Panglima Tahil ay isang ika...
# ..                                                 ...
# 106  Henero sa mga langgam ang Buceros. Ang Buceros...
# 49   Toko Kompak adalah sebuah markah tanah sejarah...
# 65   Majoor Tio Tek Ho adalah seorang birokrat Cina...
# 210  An Giang là một tỉnh thuộc vùng đồng bằng sông...
# 275  Huyện Svay Theab là một huyện nằm ở tỉnh Svay ...
#
# [93 rows x 16 columns]

# %% [markdown]
# Dataset Check

# %%
#%%
def invalid_images_as_none(batch):
    images = []
    for image_url in batch["image_url"]:
        try:
            image = Image.open(requests.get(image_url, stream=True, timeout=8).raw).convert('RGB')
        except Exception:
            image = None
        images.append(image)
    batch["image"] = images
    return batch

# %%
#%%
def get_dset(subset):
    dset = datasets.Dataset.from_pandas(dataframes[subset])
    dset = dset.with_transform(invalid_images_as_none)
    dset_uniqimg = datasets.Dataset.from_pandas(dataframes[subset].drop_duplicates("image_url"))
    dset_uniqimg = dset_uniqimg.with_transform(invalid_images_as_none)
    return dset, dset_uniqimg

# %% [markdown]
# Sequential

# %%
# #%%
# %%time
# seq_times = []
# nd = len(dset)

# non_none_count = 0
# start_time = time.time()
# for i, batch in enumerate(dset):
#     end_time = time.time()
#     seq_times.append(end_time - start_time)
#     non_none_count += 1 if batch["image"] is not None else 0
#     if i >= nd:
#         break
#     start_time = time.time()
# print("non-None Images Count:", non_none_count)

# %% [markdown]
# Parallel

# %%
#%%
def get_loader(ds, bs=8):
    return DataLoader(
        ds, batch_size=bs, num_workers=bs,
        collate_fn=lambda x: {k: [row[k] for row in x] for k in x[0]}
    )

# %%
#%%
def iterating(ds, bs=8):
    nd = len(ds)
    loader = get_loader(ds, bs)

    bs_times = []
    item_count = 0
    non_none_count = 0

    start_time = time.time()
    for batch in loader:
        item_count += len(batch['page_title'])
        end_time = time.time()
        bs_times.append(end_time - start_time)
        non_none_count += sum(map(lambda i: i is not None, batch["image"]))
        if item_count >= nd:
            break
        start_time = time.time()

    return bs_times, item_count, non_none_count

# %% [markdown]
# Do Timing

# %%
#%%
# %%time
bs8_times, item_count, non_none_count = iterating(dset, bs=8)
# Out:
# CPU times: user 30.2 ms, sys: 172 ms, total: 202 ms
# Wall time: 13.9 s

# %%
#%%
# %%time
bs16_times, item_count, non_none_count = iterating(dset, bs=16)
# Out:
# CPU times: user 27.1 ms, sys: 240 ms, total: 267 ms
# Wall time: 10.4 s

# %%
for subset in dataframes.keys():
    print(f" [{subset}]")
    dset, dset_uniqimg = get_dset(subset)

    time_st = time.time()
    _, item_cnt, non_none_cnt = iterating(dset)
    print(f"  {round((time.time()-time_st),2)}s")
    assert item_cnt == len(dset)

    time_st = time.time()
    _, item_cnt_uniq, non_none_cnt_uniq = iterating(dset_uniqimg)
    print(f"  {round((time.time()-time_st),2)}s")
    assert item_cnt_uniq == len(dset_uniqimg)

    print("Dataset Count: ", item_cnt)
    print("Unique Images: ", item_cnt_uniq, f" ({item_cnt_uniq / item_cnt :5.1%})")
    print("non-None Imgs: ", f"{non_none_cnt:3}", f" ({non_none_cnt / item_cnt :5.1%})")
    print("non-None Uniqs: ", non_none_cnt_uniq, f" ({non_none_cnt_uniq / item_cnt :5.1%})")

    print()
# Out:
#  [test]
#   13.67s
#   9.68s
# Dataset Count:  306
# Unique Images:  214  (69.9%)
# non-None Imgs:   43  (14.1%)
# non-None Uniqs:  25  ( 8.2%)
#
#  [valid]
#   14.35s
#   11.42s
# Dataset Count:  307
# Unique Images:  251  (81.8%)
# non-None Imgs:   53  (17.3%)
# non-None Uniqs:  34  (11.1%)
#
#  [train0]
#   16.6s
#   15.61s
# Dataset Count:  371
# Unique Images:  367  (98.9%)
# non-None Imgs:   54  (14.6%)
# non-None Uniqs:  52  (14.0%)
#
#  [train1]
#   16.42s
#   15.59s
# Dataset Count:  382
# Unique Images:  381  (99.7%)
# non-None Imgs:   46  (12.0%)
# non-None Uniqs:  46  (12.0%)
#
#  [train2]
#   17.02s
#   18.41s
# Dataset Count:  397
# Unique Images:  395  (99.5%)
# non-None Imgs:   77  (19.4%)
# non-None Uniqs:  76  (19.1%)
#
#  [train3]
#   17.47s
#   16.39s
# Dataset Count:  372
# Unique Images:  371  (99.7%)
# non-None Imgs:   71  (19.1%)
# non-None Uniqs:  70  (18.8%)
#
#  [train4]
#   16.21s
#   16.45s
# Dataset Count:  373
# Unique Images:  373  (100.0%)
# non-None Imgs:   49  (13.1%)
# non-None Uniqs:  49  (13.1%)
#
#  [train5]
#   15.66s
#   16.72s
# Dataset Count:  371
# Unique Images:  369  (99.5%)
# non-None Imgs:   48  (12.9%)
# non-None Uniqs:  46  (12.4%)
#
#  [train6]
#   19.01s
#   16.33s
# Dataset Count:  391
# Unique Images:  389  (99.5%)
# non-None Imgs:   54  (13.8%)
# non-None Uniqs:  54  (13.8%)
#
#  [train7]
#   17.18s
#   17.47s
# Dataset Count:  361
# Unique Images:  361  (100.0%)
# non-None Imgs:   59  (16.3%)
# non-None Uniqs:  59  (16.3%)

# %%
# Separate download, uniq_imgs.  (for reference only)
# out/img_test: 37
# out/img_valid: 29
# out/img_train0: 53
# out/img_train1: 55
# out/img_train2: 76
# out/img_train3: 71
# out/img_train4: 54
# out/img_train5: 58
# out/img_train6: 64
# out/img_train7: 70

# %%
# @title
print(f" [{subset}]")
print("Dataset Count: ", len(dset))
print("Unique Images: ", len(dset_uniqimg), f" ({len(dset_uniqimg) / len(dset) :.1%})")
print("non-None Imgs: ", f"{non_none_count:3}", f" ({non_none_count / len(dset) :.1%})")
print("non-None Uniqs: ", uniqimg_non_none_count, f" ({uniqimg_non_none_count / len(dset) :5.1%})")
# Out:
#  [test]
# Dataset Count:  306
# Unique Images:  214  (69.9%)
# non-None Imgs:   71  (23.2%)
# non-None Uniqs:  42  (13.7%)

# %%
# Out:
#  [valid]
# Dataset Count:  307
# Unique Images:  251  (81.8%)
# non-None Imgs:   34  (11.1%)
# non-None Uniqs:  21  ( 6.8%)

# %%
# Out:
#  [train0]
# Dataset Count:  371
# Unique Images:  367  (98.9%)
# non-None Imgs:   64  (17.3%)
# non-None Uniqs:  62  (16.7%)

# %%
# Out:
#  [train1]
# Dataset Count:  382
# Unique Images:  381  (99.7%)
# non-None Imgs:   43  (11.3%)
# non-None Uniqs:  43  (11.3%)

# %%
# Out:
#  [train2]
# Dataset Count:  397
# Unique Images:  395  (99.5%)
# non-None Imgs:   76  (19.1%)
# non-None Uniqs:  75  (18.9%)

# %%
# Out:
#  [train4]
# Dataset Count:  373
# Unique Images:  373  (100.0%)
# non-None Imgs:   59  (15.8%)
# non-None Uniqs:  59  (15.8%)

# %%
# batch
# Out:
# {'Unnamed: 0': [28, 29, 30, 31],
#  'language': ['id', 'vi', 'vi', 'id'],
#  'page_url': ['https://id.wikipedia.org/wiki/Kota_Kinabalu',
#   'https://vi.wikipedia.org/wiki/C%E1%BA%A7u_kh%E1%BB%89',
#   'https://vi.wikipedia.org/wiki/Singapore',
#   'https://id.wikipedia.org/wiki/CASA_C-212'],
#  'image_url': ['https://upload.wikimedia.org/wikipedia/commons/7/70/KotaKinabalu_Sabah_High-Court-01.jpg',
#   'https://upload.wikimedia.org/wikipedia/commons/c/c2/C%E1%BA%A7u_kh%E1%BB%89_%E1%BB%9F_%E1%BA%A5p_Ph%C3%BA_Th%E1%BA%A1nh%2C_x%C3%A3_Ph%C3%BA_H%E1%BB%AFu%2C_An_Ph%C3%BA.jpg',
#   'https://upload.wikimedia.org/wikipedia/commons/b/bb/KITLV_-_1404964_-_Ribeiro_%26_Co.%2C_stationers%2C_printers_%26_stampdealers_-_Singapore_-_%22Finlayson_Green%22%2C_Singapore_-_1895-1908.tif',
#   'https://upload.wikimedia.org/wikipedia/commons/b/b2/Doppler_overberg.jpg'],
#  'page_title': ['Kota Kinabalu', 'Cầu khỉ', 'Singapore', 'CASA C-212'],
#  'section_title': ['Pengadilan dan penegakan hukum',
#   'Xây dựng và sử dụng cầu khỉ',
#   'Cảng biển quốc tế lớn nhất Châu Á (1820-1960)',
#   'Album'],
#  'hierarchical_section_title': ['Kota Kinabalu / Fasilitas umum lainnya / Pengadilan dan penegakan hukum',
#   'Cầu khỉ / Xây dựng và sử dụng cầu khỉ',
#   'Singapore / Lịch sử / Cảng biển quốc tế lớn nhất Châu Á (1820-1960)',
#   'CASA C-212 / Album'],
#  'caption_reference_description': ['Pengadilan Kota Kinabalu.',
#   'Cầu khỉ ở ấp Phú Thạnh, xã Phú Hữu, An Phú.',
#   'Khu biệt thự phong cách châu Âu ở Singapore, chụp khoảng năm 1900',
#   None],
#  'caption_attribution_description': ['English: Kota Kinabalu, Sabah: High Court',
#   'Tiếng Việt: Cầu khỉ ở ấp Phú Thạnh, xã Phú Hữu, An Phú',
#   None,
#   'Doppler radar, aka "The golf-ball" at Air Force Base Overberg'],
#  'caption_alt_text_description': [None, None, None, None],
#  'mime_type': ['image/jpeg', 'image/jpeg', 'image/tiff', 'image/jpeg'],
#  'original_height': [3217, 2448, 2103, 1714],
#  'original_width': [4825, 3264, 3279, 1525],
#  'is_main_image': [True, True, True, True],
#  'attribution_passes_lang_id': [True, True, True, True],
#  'page_changed_recently': [True, True, True, True],
#  'context_page_description': ['Kota Kinabalu, sebelumnya dikenal sebagai Jesselton, adalah ibu kota Sabah, Malaysia. Kota ini juga merupakan pusat pemerintahan untuk Pantai Barat negeri Sabah. Kota ini terletak di pantai barat laut Kalimantan menghadap Laut Cina Selatan. Gunung Kinabalu, yang menjadi nama dari kota ini, berada di wilayah KK, sementara Taman Tunku Abdul Rahman, tempat perlindungan kehidupan liar, terletak juga di sini. Sampai tahun 2010, Kota Kinabalu memiliki sekitar 452.058 jiwa penduduk sementara daerah kabupaten Penampang yang juga meliputi wilayah kota ini memiliki sekitar 176.667 jiwa. Jika dijumlahkan, jumlah populasi metro adalah 628.725 jiwa.\nKota ini juga merupakan tujuan wisata utama dan pintu masuk yang populer bagi wisatawan yang mengunjungi Sabah dan juga Kalimantan. Taman Nasional Kinabalu terletak sekitar 90 km dari kota ini dan ada banyak tempat menarik bagi wisatawan di sekitar daerah ini. Kota Kinabalu juga merupakan salah satu pusat industri dan pusat perbelanjaan di wilayah Malaysia Timur. Kedua faktor ini membuat Kota Kinabalu menjadi salah satu kota yang paling cepat berkembang di Malaysia.',
#   'Cầu khỉ là một loại cầu được làm rất đơn sơ bằng đủ loại chất liệu... bắc qua kênh rạch để cho người qua lại.\nNhững cây cầu này có hoặc không có tay vịn, rất khó đi và nguy hiểm đối với những người không quen sử dụng. Những người quen dùng thì có thể gánh/khoác/đội một khối lượng cỡ 20–50 kg để đi qua cầu.\nNgười ta hình dung chỉ có những con khỉ hay leo trèo mới có thể đi được, nên đặt tên là cầu khỉ. Một ý kiến khác cho rằng chính dáng người đi lom khom như con khỉ của khách bộ hành đã khiến chiếc cầu mang cái tên này. Ngoài ra, nó còn được gọi là cầu dừa hay cầu tre.',
#   'Singapore, tên chính thức là nước Cộng hòa Singapore, là một thành bang và đảo quốc tại Đông Nam Á. Đảo quốc nằm ngoài khơi mũi phía nam của bán đảo Mã Lai và cách xích đạo 137 km về phía bắc. Lãnh thổ Singapore gồm có một đảo chính hình thoi, và khoảng 60 đảo nhỏ hơn. Singapore tách biệt với Malaysia bán đảo qua eo biển Johor ở phía bắc, và tách biệt với quần đảo Riau của Indonesia qua eo biển Singapore ở phía nam. Singapore là quốc gia đô thị hóa cao độ, chỉ còn lại ít thảm thực vật nguyên sinh. Lãnh thổ của Singapore liên tục mở rộng thông qua hoạt động cải tạo đất.\nCác hòn đảo của Singapore có người định cư vào thế kỷ thứ II Công nguyên và sau đó thuộc một số quốc gia bản địa. Năm 1819, chính trị gia Anh Quốc Stamford Raffles đã thành lập nên Singapore hiện đại với vai trò là một trạm mậu dịch của Công ty Đông Ấn Anh, hành động này được Vương quốc Johor cho phép. Anh Quốc giành được chủ quyền đối với đảo vào năm 1824, và Singapore trở thành một trong Các khu định cư Eo biển của Anh Quốc vào năm 1826. Với sự phát triển của thương mại và vận tải biển, Singapore phát triển nhanh chóng.',
#   'CASA C-212 Aviocar adalah sebuah pesawat penumpang sipil berukuran sedang bermesin turboprop yang dirancang dan diproduksi di Spanyol untuk kegunaan sipil dan militer. Pesawat jenis ini juga telah diproduksi di Indonesia di bawah lisensi oleh PT. Dirgantara Indonesia. Bahkan pada bulan Januari 2008, EADS CASA memutuskan untuk memindahkan seluruh fasilitas produksi C-212 ke PT. Dirgantara Indonesia di Bandung. PT. Dirgantara Indonesia adalah satu-satunya perusahaan pesawat yang mempunyai lisensi untuk membuat pesawat jenis ini di luar pabrik pembuat utamanya.'],
#  'image': [None, None, None, None]}

# %% [markdown]
# ---
# ### Vectorization

# %%
model = SentenceTransformer("sentence-transformers/clip-ViT-B-32").to('cuda')
# Out:
# /home/is/frederikus-h/miniconda3/envs/uwow/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
def wit_img2embed(subset, bs=8):
    dset, _ = get_dset(subset)
    loader = get_loader(dset, bs=bs)

    _images_embed = []
    _images_filt = []
    _caption = []

    for batch in tqdm(loader):
        imgs = []
        for i, img in enumerate(batch['image']):
            if img is None or img.size[0] < 50 or img.size[1] < 50:
                continue
            imgs.append(img)
            _images_filt.append(batch['image_url'][i])
            _caption.append(batch['caption_reference_description'][i])

        if imgs:   # skip batch with all None images
            img_embeds = model.encode(imgs, batch_size=bs)
            _images_embed.extend(img_embeds)

    print(f"[{subset}]  Images Counts: ", len(_images_embed), len(_images_filt), len(_caption))
    pickle.dump((_images_filt, _images_embed, _caption, []), open(f'./wit_{subset}.pkl', 'wb'))

# %%
# %%time
# wit_img2embed("test")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.61it/s]
# [test]  Images Counts:  43 43 43
# CPU times: user 2.41 s, sys: 204 ms, total: 2.61 s
# Wall time: 15 s

# %%
# %%time
for subset in dataframes.keys():
    wit_img2embed(subset)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.77it/s]
# [test]  Images Counts:  43 43 43
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:14<00:00,  2.68it/s]
# [valid]  Images Counts:  53 53 53
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 47/47 [00:16<00:00,  2.78it/s]
# [train0]  Images Counts:  55 55 55
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:15<00:00,  3.10it/s]
# [train1]  Images Counts:  49 49 49
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:17<00:00,  2.80it/s]
# [train2]  Images Counts:  81 81 81
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 47/47 [00:16<00:00,  2.86it/s]
# [train3]  Images Counts:  70 70 70
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 47/47 [00:16<00:00,  2.86it/s]
# [train4]  Images Counts:  51 51 51
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 47/47 [00:16<00:00,  2.91it/s]
# [train5]  Images Counts:  51 51 51
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 49/49 [00:17<00:00,  2.80it/s]
# [train6]  Images Counts:  56 56 56
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 46/46 [00:17<00:00,  2.66it/s]
# [train7]  Images Counts:  60 60 60
# CPU times: user 35.3 s, sys: 2.5 s, total: 37.8 s
# Wall time: 2min 43s

# %%
# !mkdir wit_emb.3090
# !mv wit_*.pkl wit_emb.3090/

# %% [markdown]
# #### Reference Embeddings: CVQA

# %%
# %%time
cvqa_dataset = load_dataset('afaji/cvqa')

cvqa_sea_subsets = [
    "('Indonesian', 'Indonesia')",
    "('Malay', 'Malaysia')",
    "('Javanese', 'Indonesia')",
    "('Minangkabau', 'Indonesia')",
    "('Sundanese', 'Indonesia')",
    "('Chinese', 'Singapore')"
]
cvqa_dataset_filt = cvqa_dataset['test'].filter(lambda x: x['Subset'] in cvqa_sea_subsets, num_proc=32)
cvqa_dataset_filt[0]
# Out:
# CPU times: user 354 ms, sys: 25.9 ms, total: 380 ms
# Wall time: 3.91 s
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=154x215>,
#  'ID': '5865939224275596310_1',
#  'Subset': "('Sundanese', 'Indonesia')",
#  'Question': 'Naon prestasina inohong dina gambar?',
#  'Translated Question': 'What is the achievement of the figure in the picture?',
#  'Options': ['Gubernur Jawa Barat',
#   'Wali kota Bandung',
#   'Gubernur DKI Jakarta',
#   'Wali kota Tasik'],
#  'Translated Options': ['Governor of West Java',
#   'Mayor of Bandung',
#   'Governor of the Special Capital Region of Jakarta',
#   'Mayor of Tasik'],
#  'Label': -1,
#  'Category': 'Public Figure and pop culture',
#  'Image Type': 'External',
#  'Image Source': 'https://upload.wikimedia.org/wikipedia/commons/0/01/Mayor_of_Bandung_Dada_Rosada.jpg',
#  'License': 'Public domain'}

# %%
# %%time
cvqa_images_filt = []
cvqa_images_embed = []
cvqa_caption = []
cvqa_culture = []
for row in tqdm(cvqa_dataset_filt):
    try:
        cvqa_images_embed.append(model.encode(row['image']))
        cvqa_images_filt.append(row['image'])
        cvqa_caption.append(row['Translated Question'] + " " + ', '.join(row['Translated Options']))
        cvqa_culture.append(eval(cvqa_dataset_filt[0]['Subset'])[0])
    except:
        print(row)
pickle.dump((cvqa_images_filt, cvqa_images_embed, cvqa_caption, cvqa_culture), open('cvqa.pkl', 'wb'))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 1687/1687 [02:17<00:00, 12.27it/s]
# CPU times: user 4min 2s, sys: 30.8 s, total: 4min 33s
# Wall time: 3min 31s

# %% [markdown]
# #### Reference Embeddings: SEA-VQA

# %%
sea_vqa_dataset = load_dataset('wit543/sea-vqa')
sea_vqa_dataset['indonesia'][0]
# Out:
# Downloading data: 100%|█████████████████████████████████████████████████████████████████████████████████| 303k/303k [00:00<00:00, 363kB/s]
# Downloading data: 100%|██████████████████████████████████████████████████████████████████████████████| 32.2k/32.2k [00:00<00:00, 77.7kB/s]
# Downloading data: 100%|███████████████████████████████████████████████████████████████████████████████| 76.9k/76.9k [00:00<00:00, 161kB/s]
# Downloading data: 100%|███████████████████████████████████████████████████████████████████████████████| 62.4k/62.4k [00:00<00:00, 157kB/s]
# Downloading data: 100%|██████████████████████████████████████████████████████████████████████████████| 14.6k/14.6k [00:00<00:00, 36.0kB/s]
# Downloading data: 100%|███████████████████████████████████████████████████████████████████████████████| 76.8k/76.8k [00:00<00:00, 150kB/s]
# Downloading data: 100%|█████████████████████████████████████████████████████████████████████████████████| 129k/129k [00:00<00:00, 293kB/s]
# Generating cambodia split: 100%|██████████████████████████████████████████████████████████████| 304/304 [00:00<00:00, 42035.68 examples/s]
# Generating indonesia split: 100%|████████████████████████████████████████████████████████████| 752/752 [00:00<00:00, 111709.46 examples/s]
# Generating laos split: 100%|████████████████████████████████████████████████████████████████████| 72/72 [00:00<00:00, 13027.47 examples/s]
# Generating malaysia split: 100%|██████████████████████████████████████████████████████████████| 189/189 [00:00<00:00, 38616.69 examples/s]
# Generating philippines split: 100%|███████████████████████████████████████████████████████████| 153/153 [00:00<00:00, 23973.72 examples/s]
# Generating singapore split: 100%|████████████████████████████████████████████████████████████████| 32/32 [00:00<00:00, 7573.94 examples/s]
# Generating thailand split: 100%|██████████████████████████████████████████████████████████████| 184/184 [00:00<00:00, 34673.01 examples/s]
# Generating vietnam split: 100%|███████████████████████████████████████████████████████████████| 313/313 [00:00<00:00, 62811.21 examples/s]
# {'question': 'What is the primary activity depicted in the image?',
#  'choice_a': 'Gathering fruits',
#  'choice_b': 'Fishing',
#  'choice_c': 'Picking herbs',
#  'choice_d': 'Planting trees',
#  'correct_answer': 'c',
#  'image_path': 'https://ich.unesco.org/img/photo/thumb/16712-HUG.jpg',
#  'image_page': 'https://ich.unesco.org/en/photo-pop-up-00973?photoID=16712',
#  'copyright': 'Photograph: Ganesh Ahsha Dalila© Dwi Ranny Pertiwi Zarman, Indonesia, 2022'}

# %%
# %%time
sea_vqa_images_filt = []
sea_vqa_images_embed = []
sea_vqa_caption = []
sea_vqa_culture = []
for key in sea_vqa_dataset.keys():
    for row in tqdm(sea_vqa_dataset[key]):
        try:
            img_opened = Image.open(requests.get(row['image_path'], stream=True).raw)
            sea_vqa_images_embed.append(model.encode(img_opened))
            sea_vqa_images_filt.append(img_opened)
            if row['correct_answer'] in ['a', 'b', 'c', 'd']:
                sea_vqa_caption.append(row['question'] + " " + row['choice_' + row['correct_answer']])
            else:
                sea_vqa_caption.append(row['question'])
            sea_vqa_culture.append(key)
        except:
            print(row)
pickle.dump((sea_vqa_images_filt, sea_vqa_images_embed, sea_vqa_caption, sea_vqa_culture), open('sea_vqa.pkl', 'wb'))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 304/304 [12:09<00:00,  2.40s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 752/752 [29:33<00:00,  2.36s/it]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 72/72 [02:25<00:00,  2.02s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 189/189 [06:13<00:00,  1.98s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 153/153 [05:52<00:00,  2.30s/it]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 32/32 [01:00<00:00,  1.88s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 184/184 [06:04<00:00,  1.98s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 313/313 [13:03<00:00,  2.50s/it]
# CPU times: user 4min 5s, sys: 4.89 s, total: 4min 10s
# Wall time: 1h 16min 34s

# %% [markdown]
# ---
# ### Embedding Similarity

# %%
import matplotlib.pyplot as plt

# %%
# %%time
sea_vqa_images_filt, sea_vqa_images_embed, sea_vqa_caption, sea_vqa_culture = pickle.load(open('sea_vqa.pkl', 'rb'))
cvqa_images_filt, cvqa_images_embed, cvqa_caption, cvqa_culture = pickle.load(open('cvqa.pkl', 'rb'))

ref_images_filt = sea_vqa_images_filt + cvqa_images_filt
ref_images_embed = sea_vqa_images_embed + cvqa_images_embed
ref_vqa_caption = sea_vqa_caption + cvqa_caption
ref_vqa_culture = sea_vqa_culture + cvqa_culture
# Out:
# CPU times: user 9.35 s, sys: 23.8 s, total: 33.2 s
# Wall time: 56.6 s

# %%
# %%time
wit_val_images_filt, wit_val_images_embed, wit_val_caption, _ = pickle.load(open('./wit_emb.3090/wit_valid.pkl', 'rb'))
wit_tst_images_filt, wit_tst_images_embed, wit_tst_caption, _ = pickle.load(open('./wit_emb.3090/wit_test.pkl', 'rb'))
# Out:
# CPU times: user 3.51 ms, sys: 0 ns, total: 3.51 ms
# Wall time: 31.7 ms

# %%
print(f"  # CVQA-set    : {len(cvqa_images_filt):>5}")
print(f" # SEA-VQA-set  : {len(sea_vqa_images_filt):>5}")
print(f"# WIT Valid-set : {len(wit_val_images_filt):>5}")
print(f"# WIT Test-set  : {len(wit_tst_images_filt):>5}")
# Out:
#   # CVQA-set    :  1687
#  # SEA-VQA-set  :  1999
# # WIT Valid-set :    53
# # WIT Test-set  :    43

# %%
# %%time
wit_val_ref_scores = model.similarity(ref_images_embed, wit_val_images_embed)

# %% [markdown]
# SEA-VQA Sample

# %%
top_k=1
last_embed = None
for idx in range(20):
    if last_embed is None:
        last_embed = ref_images_embed[idx]
    elif (last_embed == ref_images_embed[idx]).all():
        continue
    elif (last_embed != ref_images_embed[idx]).all():
        last_embed = ref_images_embed[idx]

    sorted_index = np.argsort(np.array(wit_val_ref_scores[idx]))[::-1]
    image = ref_images_filt[idx]
    caption = ref_vqa_caption[idx]
    culture = ref_vqa_culture[idx]

    print(f"******* Reference-{idx} *******")
    for rank, cand_idx in enumerate(sorted_index[:top_k]):
        print(f"=== Candidate #{rank} ===")
        print(f"Reference Caption: {caption}")
        print(f"Candidate Caption: {wit_val_caption[cand_idx]}")
        print(f"Culture: {culture}")
        print(f"Score:{wit_val_ref_scores[idx][cand_idx]}")

        fig, (ax1, ax2) = plt.subplots(1, 2)

        # Display the first PIL Image in the left subplot
        ax1.imshow(image.resize((224, 224), Image.BICUBIC))
        ax1.set_title('Reference')

        # Display the second PIL Image in the right subplot
        ax2.imshow(Image.open(requests.get(wit_val_images_filt[cand_idx], stream=True, timeout=5).raw).resize((224, 224), Image.BICUBIC))
        ax2.set_title('Candidate')
        plt.show()
    print("*"*100)
# Out:
# ******* Reference-0 *******
# === Candidate #0 ===
# Reference Caption: Which aspect of Cambodian culture is heavily illustrated in this ancient artifact? Celebratory and martial traditions
# Candidate Caption: None
# Culture: cambodia
# Score:0.7092760801315308
# ****************************************************************************************************
# ******* Reference-3 *******
# === Candidate #0 ===
# Reference Caption: To what era does this bas-relief belong? 12th-13th century
# Candidate Caption: None
# Culture: cambodia
# Score:0.7415110468864441
# ****************************************************************************************************
# ******* Reference-9 *******
# === Candidate #0 ===
# Reference Caption: What could the different colors seen in the decorations signify in Cambodian culture? Representations of different spiritual realms
# Candidate Caption: Lukisan di sebuah wihara di Sravasti, India, yang menggambarkan Angulimala sedang mencoba mengejar Buddha Gautama.
# Culture: cambodia
# Score:0.6402470469474792
# ****************************************************************************************************
# ******* Reference-11 *******
# === Candidate #0 ===
# Reference Caption: The facial expressions combined with the gestures in dance primarily aim to: Portray joy and festivity
# Candidate Caption: Lukisan di sebuah wihara di Sravasti, India, yang menggambarkan Angulimala sedang mencoba mengejar Buddha Gautama.
# Culture: cambodia
# Score:0.679588258266449
# ****************************************************************************************************
# ******* Reference-12 *******
# === Candidate #0 ===
# Reference Caption: What is the most probable time of day for this martial arts demonstration based on the lighting and shadows in the image? Midday
# Candidate Caption: Bãi biển Bo Phut
# Culture: cambodia
# Score:0.6434146761894226
# ****************************************************************************************************
# ******* Reference-17 *******
# === Candidate #0 ===
# Reference Caption: What notable feature of the event is specifically tied to Cambodian cultural practices? The use of mats for the performance
# Candidate Caption: Bãi biển Bo Phut
# Culture: cambodia
# Score:0.5956212878227234
# ****************************************************************************************************

# %%
top_k=1
last_embed = None
for idx in range(len(ref_images_filt) - 10, len(ref_images_filt)):
    if last_embed is None:
        last_embed = ref_images_embed[idx]
    elif (last_embed == ref_images_embed[idx]).all():
        continue
    elif (last_embed != ref_images_embed[idx]).all():
        last_embed = ref_images_embed[idx]

    sorted_index = np.argsort(np.array(wit_val_ref_scores[idx]))[::-1]
    image = ref_images_filt[idx]
    caption = ref_vqa_caption[idx]
    culture = ref_vqa_culture[idx]

    print(f"******* Reference-{idx} *******")
    for rank, cand_idx in enumerate(sorted_index[:top_k]):
        print(f"=== Candidate #{rank} ===")
        print(f"Reference Caption: {caption}")
        print(f"Candidate Caption: {wit_val_caption[cand_idx]}")
        print(f"Culture: {culture}")
        print(f"Score:{wit_val_ref_scores[idx][cand_idx]}")

        fig, (ax1, ax2) = plt.subplots(1, 2)

        # Display the first PIL Image in the left subplot
        ax1.imshow(image.resize((224, 224), Image.BICUBIC))
        ax1.set_title('Reference')

        # Display the second PIL Image in the right subplot
        ax2.imshow(Image.open(requests.get(wit_val_images_filt[cand_idx], stream=True, timeout=5).raw).resize((224, 224), Image.BICUBIC))
        ax2.set_title('Candidate')
        plt.show()
    print("*"*100)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ##### Mean Vector

# %%
top_k=10
last_embed = None

mean_ref_score = wit_val_ref_scores.mean(dim=0)

sorted_index = np.argsort(np.array(mean_ref_score))[::-1]

print(f"******* Mean Reference *******")
for rank, cand_idx in enumerate(sorted_index[:top_k]):
    print(f"=== Candidate #{rank} ===")
    print(f"Candidate Caption: {wit_val_caption[cand_idx]}")
    print(f"Score:{mean_ref_score[cand_idx]}")

    # Display the second PIL Image in the right subplot
    plt.imshow(Image.open(requests.get(wit_val_images_filt[cand_idx], stream=True, timeout=5).raw).resize((224, 224), Image.BICUBIC))
    plt.show()
print("*"*100)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
